# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#import dataset
ds= pd.read_csv('ecommerce_regression_dataset.csv')
ds
# Out:
#     Ad_Spend  Product_Price  Discount     Category  Weekly_Sales
# 0      11476           1228         5         Home           436
# 1       4657           1285        10         Home           360
# 2       9935           1178        25  Electronics           444
# 3       4582           1476         5         Home           322
# 4      11647           2436        25  Electronics           449
# 5       5557           1013        12         Home           373
# 6       5552           1318        15      Fashion           377
# 7       7224           1198        20      Fashion           436
# 8      14223           1088        30         Home           525
# 9       7201           1161        18         Home           413
# 10      6925           2182        15         Home           351
# 11     11834           1466        18  Electronics           483
# 12      2654           1778        18      Fashion           347
# 13      6977           1333        20      Fashion           413
# 14      5374           2437        10         Home           332
# 15      9751           2493        15  Electronics           399
# 16      5422           2310        15         Home           335
# 17     13588           1114        15  Electronics           512
# 18      7572           1548        10  Electronics           403
# 19     10292           2470        20  Electronics           426
# 20      7482           2316        30  Electronics           393
# 21      5040           2149        18         Home           350
# 22     10560           1817        20  Electronics           463
# 23      3266           2043        30  Electronics           357
# 24      2796           1313        12         Home           323
# 25      2040           1788        25         Home           346
# 26      9669           1514         5         Home           418
# 27     12169           2099        18         Home           449
# 28      5808           1890        12      Fashion           354
# 29     12830           2473        18         Home           464
# 30      9317           1217        18         Home           439
# 31      4258           1313        20  Electronics           366
# 32     13757           2086         5         Home           446
# 33      1319           1229        20      Fashion           332
# 34      4946           2161        10  Electronics           338
# 35     14369           1141        12  Electronics           511
# 36     10007           1338        18         Home           460
# 37      7932           1433        15         Home           398
# 38     12004           2330        20      Fashion           486
# 39      8397           1247        15  Electronics           401
# 40      1344           2204        15         Home           272
# 41      2163           2449         5  Electronics           251
# 42      1514           1676        10         Home           281
# 43     11960           1994        15         Home           434
# 44     10355           2180        30  Electronics           461
# 45     14230           1833        15  Electronics           472
# 46      8062           1725        25      Fashion           437
# 47     12945           1110        10  Electronics           476
# 48      6559           1223        15  Electronics           379
# 49      8350           1287        25  Electronics           427

# %%
ds.columns
# Out:
# Index(['Ad_Spend', 'Product_Price', 'Discount', 'Category', 'Weekly_Sales'], dtype='object')

# %%
#splitting dataset into Independent and Dependent variables
x=ds[['Ad_Spend', 'Product_Price', 'Discount', 'Category']]
y=ds[['Weekly_Sales']]

# %%
from sklearn.preprocessing import OneHotEncoder
ohe= OneHotEncoder(sparse_output=False)
encode_data= ohe.fit_transform(x[['Category']])
encode_data

column_name= ohe.get_feature_names_out(['Category'])
en_df= pd.DataFrame(encode_data, columns= column_name)
en_df

x = pd.concat([x,en_df], axis=1)
x

x= x.drop(columns=['Category'])
x
# Out:
#     Ad_Spend  Product_Price  Discount  Category_Electronics  Category_Fashion  \
# 0      11476           1228         5                   0.0               0.0
# 1       4657           1285        10                   0.0               0.0
# 2       9935           1178        25                   1.0               0.0
# 3       4582           1476         5                   0.0               0.0
# 4      11647           2436        25                   1.0               0.0
# 5       5557           1013        12                   0.0               0.0
# 6       5552           1318        15                   0.0               1.0
# 7       7224           1198        20                   0.0               1.0
# 8      14223           1088        30                   0.0               0.0
# 9       7201           1161        18                   0.0               0.0
# 10      6925           2182        15                   0.0               0.0
# 11     11834           1466        18                   1.0               0.0
# 12      2654           1778        18                   0.0               1.0
# 13      6977           1333        20                   0.0               1.0
# 14      5374           2437        10                   0.0               0.0
# 15      9751           2493        15                   1.0               0.0
# 16      5422           2310        15                   0.0               0.0
# 17     13588           1114        15                   1.0               0.0
# 18      7572           1548        10                   1.0               0.0
# 19     10292           2470        20                   1.0               0.0
# 20      7482           2316        30                   1.0               0.0
# 21      5040           2149        18                   0.0               0.0
# 22     10560           1817        20                   1.0               0.0
# 23      3266           2043        30                   1.0               0.0
# 24      2796           1313        12                   0.0               0.0
# 25      2040           1788        25                   0.0               0.0
# 26      9669           1514         5                   0.0               0.0
# 27     12169           2099        18                   0.0               0.0
# 28      5808           1890        12                   0.0               1.0
# 29     12830           2473        18                   0.0               0.0
# 30      9317           1217        18                   0.0               0.0
# 31      4258           1313        20                   1.0               0.0
# 32     13757           2086         5                   0.0               0.0
# 33      1319           1229        20                   0.0               1.0
# 34      4946           2161        10                   1.0               0.0
# 35     14369           1141        12                   1.0               0.0
# 36     10007           1338        18                   0.0               0.0
# 37      7932           1433        15                   0.0               0.0
# 38     12004           2330        20                   0.0               1.0
# 39      8397           1247        15                   1.0               0.0
# 40      1344           2204        15                   0.0               0.0
# 41      2163           2449         5                   1.0               0.0
# 42      1514           1676        10                   0.0               0.0
# 43     11960           1994        15                   0.0               0.0
# 44     10355           2180        30                   1.0               0.0
# 45     14230           1833        15                   1.0               0.0
# 46      8062           1725        25                   0.0               1.0
# 47     12945           1110        10                   1.0               0.0
# 48      6559           1223        15                   1.0               0.0
# 49      8350           1287        25                   1.0               0.0
#
#     Category_Home
# 0             1.0
# 1             1.0
# 2             0.0
# 3             1.0
# 4             0.0
# 5             1.0
# 6             0.0
# 7             0.0
# 8             1.0
# 9             1.0
# 10            1.0
# 11            0.0
# 12            0.0
# 13            0.0
# 14            1.0
# 15            0.0
# 16            1.0
# 17            0.0
# 18            0.0
# 19            0.0
# 20            0.0
# 21            1.0
# 22            0.0
# 23            0.0
# 24            1.0
# 25            1.0
# 26            1.0
# 27            1.0
# 28            0.0
# 29            1.0
# 30            1.0
# 31            0.0
# 32            1.0
# 33            0.0
# 34            0.0
# 35            0.0
# 36            1.0
# 37            1.0
# 38            0.0
# 39            0.0
# 40            1.0
# 41            0.0
# 42            1.0
# 43            1.0
# 44            0.0
# 45            0.0
# 46            0.0
# 47            0.0
# 48            0.0
# 49            0.0

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y, test_size=0.2, random_state=1)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_test)
y_pred
# Out:
# array([[450.49045725],
#        [504.17754582],
#        [283.41236657],
#        [455.80861441],
#        [468.08380046],
#        [331.87270945],
#        [395.09390998],
#        [447.66322988],
#        [430.06069926],
#        [370.07044585]])

# %%
y_test
# Out:
#     Weekly_Sales
# 27           449
# 35           511
# 40           272
# 38           486
# 2            444
# 3            322
# 48           379
# 29           464
# 46           437
# 31           366

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,y_pred)
score
# Out:
# 0.9545485899011444
